# %%
import socket
from xbox import XboxPad

# %%
sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
xb = XboxPad()
# Out:
# Gamepad connected.

# %%
try:
    while True:
        event = xb.get_event()
        if event != None:
            code, state = event
            print('code:',code.rjust(10),'\tstate:',state)
            sock.sendto((code+':'+str(state)).encode(),
                        ('192.168.43.143',6666))
except KeyboardInterrupt:
    pass
# Out:
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:      ABS_Y 	state: 1516
# code:      ABS_Y 	state: 1525
# code:      ABS_Y 	state: 1540
# code:      ABS_Y 	state: 1566
# code:      ABS_Y 	state: 1747
# code:      ABS_Y 	state: 1759
# code:      ABS_Y 	state: 1782
# code:      ABS_Y 	state: 1928
# code:      ABS_Y 	state: 2000
# code:      ABS_X 	state: 1501
# code:      ABS_X 	state: 1504
# code:      ABS_X 	state: 1506
# code:      ABS_X 	state: 1509
# code:      ABS_X 	state: 1511
# code:      ABS_X 	state: 1513
# code:      ABS_Y 	state: 1957
# code:      ABS_X 	state: 1510
# code:      ABS_Y 	state: 1945
# code:      ABS_X 	state: 1501
# code:      ABS_Y 	state: 1797
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1602
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1579
# code:      ABS_Y 	state: 1587
# code:      ABS_Y 	state: 1602
# code:      ABS_Y 	state: 1625
# code:      ABS_Y 	state: 1767
# code:      ABS_Y 	state: 1774
# code:      ABS_Y 	state: 1787
# code:      ABS_Y 	state: 1804
# code:      ABS_Y 	state: 1823
# code:      ABS_Y 	state: 1844
# code:      ABS_Y 	state: 1865
# code:      ABS_Y 	state: 1885
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1987
# code:      ABS_Y 	state: 1972
# code:      ABS_Y 	state: 1794
# code:      ABS_Y 	state: 1608
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1545
# code:      ABS_Y 	state: 1555
# code:      ABS_Y 	state: 1576
# code:      ABS_Y 	state: 1740
# code:      ABS_Y 	state: 1753
# code:      ABS_Y 	state: 1778
# code:      ABS_Y 	state: 1924
# code:      ABS_Y 	state: 1937
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1933
# code:      ABS_Y 	state: 1779
# code:      ABS_Y 	state: 1514
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1640
# code:      ABS_Y 	state: 1652
# code:      ABS_Y 	state: 1674
# code:      ABS_Y 	state: 1808
# code:      ABS_Y 	state: 1820
# code:      ABS_Y 	state: 1838
# code:      ABS_Y 	state: 1861
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1991
# code:      ABS_Y 	state: 1979
# code:      ABS_Y 	state: 1953
# code:      ABS_Y 	state: 1726
# code:      ABS_Y 	state: 1592
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1586
# code:      ABS_Y 	state: 1595
# code:      ABS_Y 	state: 1616
# code:      ABS_Y 	state: 1775
# code:      ABS_Y 	state: 1788
# code:      ABS_Y 	state: 1810
# code:      ABS_Y 	state: 1949
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1976
# code:      ABS_Y 	state: 1967
# code:      ABS_Y 	state: 1951
# code:      ABS_Y 	state: 1928
# code:      ABS_Y 	state: 1788
# code:      ABS_Y 	state: 1769
# code:      ABS_Y 	state: 1584
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1582
# code:      ABS_Y 	state: 1588
# code:      ABS_Y 	state: 1601
# code:      ABS_Y 	state: 1616
# code:      ABS_Y 	state: 1634
# code:      ABS_Y 	state: 1655
# code:      ABS_Y 	state: 1676
# code:      ABS_Y 	state: 1696
# code:      ABS_Y 	state: 1717
# code:      ABS_X 	state: 1513
# code:      ABS_Y 	state: 1736
# code:      ABS_X 	state: 1526
# code:      ABS_Y 	state: 1759
# code:      ABS_X 	state: 1538
# code:      ABS_Y 	state: 1783
# code:      ABS_X 	state: 1548
# code:      ABS_Y 	state: 1807
# code:      ABS_X 	state: 1557
# code:      ABS_Y 	state: 1833
# code:      ABS_X 	state: 1564
# code:      ABS_Y 	state: 1967
# code:      ABS_X 	state: 1569
# code:      ABS_Y 	state: 2000
# code:      ABS_X 	state: 1574
# code:      ABS_X 	state: 1577
# code:      ABS_X 	state: 1580
# code:      ABS_X 	state: 1583
# code:      ABS_X 	state: 1586
# code:      ABS_X 	state: 1588
# code:      ABS_X 	state: 1590
# code:      ABS_X 	state: 1588
# code:      ABS_X 	state: 1581
# code:      ABS_X 	state: 1573
# code:      ABS_X 	state: 1562
# code:      ABS_X 	state: 1550
# code:      ABS_X 	state: 1537
# code:      ABS_X 	state: 1525
# code:      ABS_Y 	state: 1953
# code:      ABS_X 	state: 1516
# code:      ABS_Y 	state: 1944
# code:      ABS_X 	state: 1509
# code:      ABS_Y 	state: 1920
# code:      ABS_X 	state: 1502
# code:      ABS_Y 	state: 1726
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1700
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1398
# code:      ABS_Y 	state: 1389
# code:      ABS_Y 	state: 1369
# code:      ABS_Y 	state: 1344
# code:      ABS_Y 	state: 1188
# code:      ABS_Y 	state: 1182
# code:      ABS_Y 	state: 1172
# code:      ABS_Y 	state: 1163
# code:      ABS_Y 	state: 1154
# code:      ABS_Y 	state: 1147
# code:      ABS_Y 	state: 1140
# code:      ABS_X 	state: 1495
# code:      ABS_Y 	state: 1135
# code:      ABS_X 	state: 1489
# code:      ABS_Y 	state: 1131
# code:      ABS_X 	state: 1484
# code:      ABS_Y 	state: 1128
# code:      ABS_X 	state: 1481
# code:      ABS_Y 	state: 1125
# code:      ABS_X 	state: 1478
# code:      ABS_Y 	state: 1124
# code:      ABS_X 	state: 1484
# code:      ABS_X 	state: 1494
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1135
# code:      ABS_Y 	state: 1368
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1511
# code:      ABS_Y 	state: 1533
# code:      ABS_Y 	state: 1703
# code:      ABS_Y 	state: 1719
# code:      ABS_Y 	state: 1860
# code:      ABS_Y 	state: 1873
# code:      ABS_Y 	state: 2000
# code:      ABS_X 	state: 1503
# code:      ABS_Y 	state: 1814
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1401
# code:      ABS_Y 	state: 1394
# code:      ABS_Y 	state: 1377
# code:      ABS_Y 	state: 1352
# code:      ABS_Y 	state: 1191
# code:      ABS_Y 	state: 1182
# code:      ABS_Y 	state: 1170
# code:      ABS_Y 	state: 1154
# code:      ABS_Y 	state: 1135
# code:      ABS_Y 	state: 1116
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1056
# code:      ABS_Y 	state: 1078
# code:      ABS_Y 	state: 1294
# code:      ABS_Y 	state: 1317
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1359
# code:      ABS_Y 	state: 1340
# code:      ABS_Y 	state: 1181
# code:      ABS_Y 	state: 1170
# code:      ABS_Y 	state: 1146
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1039
# code:      ABS_Y 	state: 1057
# code:      ABS_Y 	state: 1251
# code:      ABS_Y 	state: 1277
# code:      ABS_Y 	state: 1490
# code:      ABS_Y 	state: 1500
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:      ABS_Y 	state: 1560
# code:      ABS_Y 	state: 1572
# code:      ABS_Y 	state: 1598
# code:      ABS_Y 	state: 1798
# code:      ABS_Y 	state: 1817
# code:      ABS_Y 	state: 1989
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1904
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1551
# code:      ABS_Y 	state: 1567
# code:      ABS_Y 	state: 1728
# code:      ABS_Y 	state: 1744
# code:      ABS_Y 	state: 1770
# code:      ABS_Y 	state: 1915
# code:      ABS_Y 	state: 1923
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1935
# code:      ABS_Y 	state: 1769
# code:      ABS_Y 	state: 1422
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1594
# code:      ABS_Y 	state: 1609
# code:      ABS_Y 	state: 1761
# code:      ABS_Y 	state: 1775
# code:      ABS_Y 	state: 1800
# code:      ABS_Y 	state: 1954
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1959
# code:      ABS_Y 	state: 1933
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1505
# code:      ABS_Y 	state: 1518
# code:      ABS_Y 	state: 1541
# code:      ABS_Y 	state: 1723
# code:      ABS_Y 	state: 1739
# code:      ABS_Y 	state: 1872
# code:      ABS_Y 	state: 1883
# code:      ABS_Y 	state: 1904
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1847
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1525
# code:      ABS_Y 	state: 1537
# code:      ABS_Y 	state: 1559
# code:      ABS_Y 	state: 1728
# code:      ABS_Y 	state: 1743
# code:      ABS_Y 	state: 1876
# code:      ABS_Y 	state: 1887
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1905
# code:      ABS_Y 	state: 1585
# code:      ABS_Y 	state: 1500
# code:      ABS_X 	state: 1466
# code:      ABS_X 	state: 1451
# code:      ABS_X 	state: 1303
# code:      ABS_X 	state: 1286
# code:      ABS_X 	state: 1124
# code:      ABS_X 	state: 1111
# code:      ABS_X 	state: 1000
# code:      ABS_Y 	state: 1501
# code:      ABS_Y 	state: 1500
# code:      ABS_X 	state: 1008
# code:      ABS_X 	state: 1430
# code:      ABS_X 	state: 1515
# code:      ABS_X 	state: 1500
# code:      ABS_X 	state: 1601
# code:      ABS_X 	state: 1613
# code:      ABS_X 	state: 1639
# code:      ABS_X 	state: 1806
# code:      ABS_X 	state: 1943
# code:      ABS_X 	state: 2000
# code:      ABS_X 	state: 1800
# code:      ABS_X 	state: 1465
# code:      ABS_X 	state: 1500
# code:      ABS_X 	state: 1308
# code:      ABS_X 	state: 1282
# code:      ABS_X 	state: 1047
# code:      ABS_X 	state: 1000
# code:      ABS_X 	state: 1114
# code:      ABS_X 	state: 1676
# code:      ABS_X 	state: 1500
# code:      ABS_X 	state: 1611
# code:      ABS_X 	state: 1634
# code:      ABS_X 	state: 1843
# code:      ABS_X 	state: 1980
# code:      ABS_X 	state: 2000
# code:      ABS_X 	state: 1662
# code:      ABS_X 	state: 1467
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1406
# code:      ABS_Y 	state: 1395
# code:      ABS_X 	state: 1451
# code:      ABS_Y 	state: 1251
# code:      ABS_X 	state: 1446
# code:      ABS_Y 	state: 1231
# code:      ABS_X 	state: 1440
# code:      ABS_Y 	state: 1064
# code:      ABS_X 	state: 1433
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1428
# code:      ABS_X 	state: 1424
# code:      ABS_X 	state: 1420
# code:      ABS_X 	state: 1418
# code:      ABS_X 	state: 1416
# code:      ABS_X 	state: 1414
# code:      ABS_X 	state: 1413
# code:      ABS_X 	state: 1411
# code:      ABS_X 	state: 1416
# code:      ABS_Y 	state: 1069
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1569
# code:      ABS_Y 	state: 1500
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:      ABS_Y 	state: 1515
# code:      ABS_Y 	state: 1716
# code:      ABS_Y 	state: 1741
# code:      ABS_Y 	state: 1938
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1966
# code:      ABS_Y 	state: 1955
# code:      ABS_Y 	state: 1799
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1435
# code:      ABS_Y 	state: 1421
# code:      ABS_Y 	state: 1395
# code:      ABS_Y 	state: 1205
# code:      ABS_Y 	state: 1192
# code:      ABS_Y 	state: 1173
# code:      ABS_Y 	state: 1039
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1203
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1590
# code:      ABS_Y 	state: 1601
# code:      ABS_Y 	state: 1625
# code:      ABS_Y 	state: 1789
# code:      ABS_Y 	state: 1803
# code:      ABS_Y 	state: 1826
# code:      ABS_Y 	state: 1996
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1827
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1401
# code:      ABS_X 	state: 1492
# code:      ABS_Y 	state: 1395
# code:      ABS_X 	state: 1480
# code:      ABS_Y 	state: 1379
# code:      ABS_X 	state: 1461
# code:      ABS_Y 	state: 1354
# code:      ABS_X 	state: 1437
# code:      ABS_Y 	state: 1195
# code:      ABS_X 	state: 1274
# code:      ABS_Y 	state: 1185
# code:      ABS_X 	state: 1264
# code:      ABS_Y 	state: 1171
# code:      ABS_X 	state: 1247
# code:      ABS_Y 	state: 1149
# code:      ABS_X 	state: 1232
# code:      ABS_Y 	state: 1131
# code:      ABS_X 	state: 1220
# code:      ABS_Y 	state: 1117
# code:      ABS_X 	state: 1211
# code:      ABS_Y 	state: 1105
# code:      ABS_X 	state: 1207
# code:      ABS_Y 	state: 1094
# code:      ABS_X 	state: 1211
# code:      ABS_Y 	state: 1080
# code:      ABS_X 	state: 1221
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1239
# code:      ABS_X 	state: 1260
# code:      ABS_X 	state: 1284
# code:      ABS_X 	state: 1305
# code:      ABS_X 	state: 1322
# code:      ABS_X 	state: 1337
# code:      ABS_X 	state: 1348
# code:      ABS_X 	state: 1357
# code:      ABS_X 	state: 1365
# code:      ABS_X 	state: 1374
# code:      ABS_X 	state: 1385
# code:      ABS_X 	state: 1394
# code:      ABS_X 	state: 1401
# code:      ABS_X 	state: 1407
# code:      ABS_X 	state: 1412
# code:      ABS_X 	state: 1415
# code:      ABS_X 	state: 1418
# code:      ABS_X 	state: 1421
# code:      ABS_X 	state: 1423
# code:      ABS_X 	state: 1429
# code:      ABS_X 	state: 1437
# code:      ABS_X 	state: 1450
# code:      ABS_X 	state: 1461
# code:      ABS_X 	state: 1471
# code:      ABS_X 	state: 1478
# code:      ABS_X 	state: 1484
# code:      ABS_X 	state: 1489
# code:      ABS_X 	state: 1493
# code:      ABS_X 	state: 1496
# code:      ABS_X 	state: 1499
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1386
# code:      ABS_Y 	state: 1371
# code:      ABS_Y 	state: 1222
# code:      ABS_Y 	state: 1207
# code:      ABS_Y 	state: 1186
# code:      ABS_Y 	state: 1052
# code:      ABS_Y 	state: 1043
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1157
# code:      ABS_Y 	state: 1604
# code:      ABS_Y 	state: 1477
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1385
# code:      ABS_Y 	state: 1374
# code:      ABS_Y 	state: 1350
# code:      ABS_X 	state: 1461
# code:      ABS_Y 	state: 1195
# code:      ABS_X 	state: 1452
# code:      ABS_Y 	state: 1188
# code:      ABS_X 	state: 1437
# code:      ABS_Y 	state: 1175
# code:      ABS_X 	state: 1418
# code:      ABS_Y 	state: 1157
# code:      ABS_X 	state: 1399
# code:      ABS_Y 	state: 1132
# code:      ABS_X 	state: 1381
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1367
# code:      ABS_X 	state: 1356
# code:      ABS_X 	state: 1346
# code:      ABS_X 	state: 1339
# code:      ABS_X 	state: 1333
# code:      ABS_X 	state: 1329
# code:      ABS_X 	state: 1325
# code:      ABS_X 	state: 1322
# code:      ABS_X 	state: 1319
# code:      ABS_X 	state: 1317
# code:      ABS_X 	state: 1316
# code:      ABS_X 	state: 1314
# code:      ABS_X 	state: 1312
# code:      ABS_X 	state: 1311
# code:      ABS_X 	state: 1313
# code:      ABS_X 	state: 1317
# code:      ABS_X 	state: 1322
# code:      ABS_X 	state: 1327
# code:      ABS_X 	state: 1331
# code:      ABS_X 	state: 1335
# code:      ABS_X 	state: 1337
# code:      ABS_X 	state: 1340
# code:      ABS_X 	state: 1343
# code:      ABS_X 	state: 1345
# code:      ABS_X 	state: 1347
# code:      ABS_X 	state: 1349
# code:      ABS_X 	state: 1355
# code:      ABS_X 	state: 1363
# code:      ABS_X 	state: 1371
# code:      ABS_X 	state: 1378
# code:      ABS_X 	state: 1383
# code:      ABS_X 	state: 1387
# code:      ABS_X 	state: 1390
# code:      ABS_X 	state: 1393
# code:      ABS_X 	state: 1395
# code:      ABS_X 	state: 1398
# code:      ABS_X 	state: 1400
# code:      ABS_X 	state: 1402
# code:      ABS_X 	state: 1397
# code:      ABS_X 	state: 1391
# code:      ABS_X 	state: 1386
# code:      ABS_X 	state: 1382
# code:      ABS_X 	state: 1379
# code:      ABS_X 	state: 1377
# code:      ABS_X 	state: 1375
# code:      ABS_X 	state: 1373
# code:      ABS_X 	state: 1371
# code:      ABS_X 	state: 1370
# code:      ABS_X 	state: 1368
# code:      ABS_X 	state: 1367
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1344
# code:      ABS_Y 	state: 1596
# code:      ABS_Y 	state: 1454
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1486
# code:      ABS_Y 	state: 1461
# code:      ABS_Y 	state: 1435
# code:      ABS_Y 	state: 1281
# code:      ABS_Y 	state: 1274
# code:      ABS_Y 	state: 1259
# code:      ABS_Y 	state: 1238
# code:      ABS_Y 	state: 1213
# code:      ABS_Y 	state: 1048
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1496
# code:      ABS_X 	state: 1490
# code:      ABS_X 	state: 1484
# code:      ABS_X 	state: 1480
# code:      ABS_X 	state: 1476
# code:      ABS_X 	state: 1474
# code:      ABS_X 	state: 1471
# code:      ABS_X 	state: 1470
# code:      ABS_X 	state: 1468
# code:      ABS_X 	state: 1466
# code:      ABS_X 	state: 1465
# code:      ABS_X 	state: 1463
# code:      ABS_X 	state: 1475
# code:      ABS_Y 	state: 1485
# code:      ABS_X 	state: 1513
# code:      ABS_Y 	state: 1507
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1499
# code:      ABS_Y 	state: 1357
# code:      ABS_Y 	state: 1343
# code:      ABS_Y 	state: 1317
# code:      ABS_Y 	state: 1156
# code:      ABS_Y 	state: 1149
# code:      ABS_Y 	state: 1133
# code:      ABS_Y 	state: 1113
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1491
# code:      ABS_X 	state: 1481
# code:      ABS_X 	state: 1473
# code:      ABS_X 	state: 1466
# code:      ABS_X 	state: 1461
# code:      ABS_X 	state: 1457
# code:      ABS_X 	state: 1453
# code:      ABS_X 	state: 1451
# code:      ABS_X 	state: 1448
# code:      ABS_X 	state: 1447
# code:      ABS_X 	state: 1445
# code:      ABS_X 	state: 1443
# code:      ABS_X 	state: 1442
# code:      ABS_X 	state: 1441
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1488
# code:      ABS_Y 	state: 1470
# code:      ABS_Y 	state: 1452
# code:      ABS_Y 	state: 1435
# code:      ABS_Y 	state: 1417
# code:      ABS_Y 	state: 1395
# code:      ABS_Y 	state: 1262
# code:      ABS_Y 	state: 1257
# code:      ABS_Y 	state: 1239
# code:      ABS_Y 	state: 1216
# code:      ABS_Y 	state: 1069
# code:      ABS_Y 	state: 1059
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1495
# code:      ABS_X 	state: 1490
# code:      ABS_X 	state: 1486
# code:      ABS_X 	state: 1481
# code:      ABS_X 	state: 1477
# code:      ABS_X 	state: 1474
# code:      ABS_X 	state: 1471
# code:      ABS_X 	state: 1469
# code:      ABS_X 	state: 1467
# code:      ABS_X 	state: 1466
# code:      ABS_X 	state: 1464
# code:      ABS_X 	state: 1462
# code:      ABS_X 	state: 1461
# code:      ABS_Y 	state: 1199
# code:      ABS_X 	state: 1505
# code:      ABS_Y 	state: 1577
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1393
# code:      ABS_Y 	state: 1387
# code:      ABS_Y 	state: 1377
# code:      ABS_Y 	state: 1359
# code:      ABS_Y 	state: 1340
# code:      ABS_Y 	state: 1321
# code:      ABS_Y 	state: 1300
# code:      ABS_Y 	state: 1279
# code:      ABS_Y 	state: 1258
# code:      ABS_Y 	state: 1239
# code:      ABS_Y 	state: 1220
# code:      ABS_Y 	state: 1203
# code:      ABS_Y 	state: 1188
# code:      ABS_Y 	state: 1175
# code:      ABS_Y 	state: 1163
# code:      ABS_Y 	state: 1152
# code:      ABS_Y 	state: 1141
# code:      ABS_Y 	state: 1129
# code:      ABS_Y 	state: 1119
# code:      ABS_Y 	state: 1108
# code:      ABS_Y 	state: 1097
# code:      ABS_Y 	state: 1086
# code:      ABS_Y 	state: 1075
# code:      ABS_Y 	state: 1065
# code:      ABS_Y 	state: 1058
# code:      ABS_X 	state: 1498
# code:      ABS_Y 	state: 1051
# code:      ABS_X 	state: 1496
# code:      ABS_Y 	state: 1044
# code:      ABS_X 	state: 1495
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1493
# code:      ABS_X 	state: 1491
# code:      ABS_X 	state: 1490
# code:      ABS_X 	state: 1488
# code:      ABS_X 	state: 1486
# code:      ABS_X 	state: 1484
# code:      ABS_X 	state: 1482
# code:      ABS_X 	state: 1481
# code:      ABS_X 	state: 1479
# code:      ABS_X 	state: 1477
# code:      ABS_X 	state: 1476
# code:      ABS_X 	state: 1474
# code:      ABS_X 	state: 1473
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1389
# code:      ABS_Y 	state: 1383
# code:      ABS_Y 	state: 1372
# code:      ABS_Y 	state: 1350
# code:      ABS_Y 	state: 1328
# code:      ABS_Y 	state: 1182
# code:      ABS_X 	state: 1487
# code:      ABS_Y 	state: 1173
# code:      ABS_X 	state: 1476
# code:      ABS_Y 	state: 1161
# code:      ABS_X 	state: 1468
# code:      ABS_Y 	state: 1143
# code:      ABS_X 	state: 1461
# code:      ABS_Y 	state: 1124
# code:      ABS_X 	state: 1455
# code:      ABS_Y 	state: 1099
# code:      ABS_X 	state: 1452
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1449
# code:      ABS_X 	state: 1447
# code:      ABS_X 	state: 1446
# code:      ABS_X 	state: 1444
# code:      ABS_X 	state: 1442
# code:      ABS_X 	state: 1441
# code:      ABS_X 	state: 1439
# code:      ABS_X 	state: 1436
# code:      ABS_X 	state: 1433
# code:      ABS_X 	state: 1431
# code:      ABS_X 	state: 1429
# code:      ABS_X 	state: 1427
# code:      ABS_X 	state: 1425
# code:      ABS_X 	state: 1424
# code:      ABS_X 	state: 1422
# code:      ABS_X 	state: 1424
# code:      ABS_X 	state: 1427
# code:      ABS_X 	state: 1429
# code:      ABS_X 	state: 1431
# code:      ABS_X 	state: 1433
# code:      ABS_X 	state: 1439
# code:      ABS_X 	state: 1445
# code:      ABS_X 	state: 1455
# code:      ABS_X 	state: 1465
# code:      ABS_X 	state: 1476
# code:      ABS_X 	state: 1486
# code:      ABS_X 	state: 1495
# code:      ABS_X 	state: 1500
# code:      ABS_X 	state: 1497
# code:      ABS_X 	state: 1493
# code:      ABS_X 	state: 1489
# code:      ABS_X 	state: 1486
# code:      ABS_X 	state: 1484
# code:      ABS_X 	state: 1482
# code:      ABS_X 	state: 1480
# code:      ABS_X 	state: 1478
# code:      ABS_X 	state: 1476
# code:      ABS_X 	state: 1474
# code:      ABS_X 	state: 1473
# code:      ABS_X 	state: 1472
# code:      ABS_X 	state: 1469
# code:      ABS_X 	state: 1467
# code:      ABS_X 	state: 1465
# code:      ABS_X 	state: 1464
# code:      ABS_X 	state: 1475
# code:      ABS_Y 	state: 1316
# code:      ABS_X 	state: 1516
# code:      ABS_Y 	state: 1582
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1479
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1482
# code:      ABS_Y 	state: 1457
# code:      ABS_Y 	state: 1321
# code:      ABS_Y 	state: 1309
# code:      ABS_Y 	state: 1292
# code:      ABS_Y 	state: 1268
# code:      ABS_Y 	state: 1130
# code:      ABS_Y 	state: 1120
# code:      ABS_Y 	state: 1100
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1115
# code:      ABS_Y 	state: 1254
# code:      ABS_Y 	state: 1470
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1412
# code:      ABS_Y 	state: 1397
# code:      ABS_Y 	state: 1210
# code:      ABS_Y 	state: 1190
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1052
# code:      ABS_Y 	state: 1237
# code:      ABS_Y 	state: 1531
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1491
# code:      ABS_Y 	state: 1465
# code:      ABS_Y 	state: 1307
# code:      ABS_Y 	state: 1291
# code:      ABS_Y 	state: 1132
# code:      ABS_Y 	state: 1110
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1008
# code:      ABS_Y 	state: 1028
# code:      ABS_Y 	state: 1220
# code:      ABS_Y 	state: 1424
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1316
# code:      ABS_Y 	state: 1055
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1098
# code:      ABS_Y 	state: 1117
# code:      ABS_Y 	state: 1342
# code:      ABS_Y 	state: 1356
# code:      ABS_Y 	state: 1377
# code:      ABS_Y 	state: 1394
# code:      ABS_Y 	state: 1408
# code:      ABS_Y 	state: 1420
# code:      ABS_Y 	state: 1428
# code:      ABS_Y 	state: 1419
# code:      ABS_Y 	state: 1268
# code:      ABS_Y 	state: 1131
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1029
# code:      ABS_Y 	state: 1052
# code:      ABS_Y 	state: 1312
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1374
# code:      ABS_Y 	state: 1163
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1040
# code:      ABS_Y 	state: 1058
# code:      ABS_Y 	state: 1256
# code:      ABS_Y 	state: 1398
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1353
# code:      ABS_Y 	state: 1127
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1495
# code:      ABS_X 	state: 1489
# code:      ABS_X 	state: 1484
# code:      ABS_X 	state: 1480
# code:      ABS_X 	state: 1477
# code:      ABS_X 	state: 1474
# code:      ABS_X 	state: 1472
# code:      ABS_X 	state: 1471
# code:      ABS_X 	state: 1469
# code:      ABS_X 	state: 1471
# code:      ABS_X 	state: 1479
# code:      ABS_X 	state: 1489
# code:      ABS_Y 	state: 1023
# code:      ABS_X 	state: 1497
# code:      ABS_Y 	state: 1045
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1309
# code:      ABS_Y 	state: 1466
# code:      ABS_Y 	state: 1490
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1331
# code:      ABS_Y 	state: 1136
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1008
# code:      ABS_Y 	state: 1032
# code:      ABS_Y 	state: 1284
# code:      ABS_Y 	state: 1453
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1412
# code:      ABS_Y 	state: 1224
# code:      ABS_Y 	state: 1008
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1034
# code:      ABS_Y 	state: 1047
# code:      ABS_Y 	state: 1071
# code:      ABS_Y 	state: 1257
# code:      ABS_Y 	state: 1279
# code:      ABS_Y 	state: 1469
# code:      ABS_Y 	state: 1488
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1410
# code:      ABS_Y 	state: 1390
# code:      ABS_Y 	state: 1161
# code:      ABS_Y 	state: 1134
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1497
# code:      ABS_X 	state: 1488
# code:      ABS_X 	state: 1480
# code:      ABS_X 	state: 1474
# code:      ABS_X 	state: 1469
# code:      ABS_X 	state: 1465
# code:      ABS_X 	state: 1462
# code:      ABS_X 	state: 1459
# code:      ABS_X 	state: 1457
# code:      ABS_X 	state: 1455
# code:      ABS_X 	state: 1453
# code:      ABS_X 	state: 1451
# code:      ABS_X 	state: 1450
# code:      ABS_X 	state: 1448
# code:      ABS_X 	state: 1444
# code:      ABS_X 	state: 1439
# code:      ABS_X 	state: 1434
# code:      ABS_X 	state: 1430
# code:      ABS_X 	state: 1427
# code:      ABS_X 	state: 1424
# code:      ABS_X 	state: 1422
# code:      ABS_X 	state: 1421
# code:      ABS_X 	state: 1419
# code:      ABS_X 	state: 1417
# code:      ABS_X 	state: 1416
# code:      ABS_X 	state: 1410
# code:      ABS_X 	state: 1404
# code:      ABS_X 	state: 1413
# code:      ABS_Y 	state: 1106
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1598
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1391
# code:      ABS_Y 	state: 1381
# code:      ABS_Y 	state: 1244
# code:      ABS_Y 	state: 1221
# code:      ABS_Y 	state: 1026
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1491
# code:      ABS_X 	state: 1484
# code:      ABS_X 	state: 1477
# code:      ABS_X 	state: 1472
# code:      ABS_X 	state: 1468
# code:      ABS_X 	state: 1464
# code:      ABS_X 	state: 1459
# code:      ABS_X 	state: 1454
# code:      ABS_X 	state: 1450
# code:      ABS_X 	state: 1447
# code:      ABS_X 	state: 1444
# code:      ABS_X 	state: 1442
# code:      ABS_X 	state: 1440
# code:      ABS_X 	state: 1439
# code:      ABS_X 	state: 1437
# code:      ABS_X 	state: 1435
# code:      ABS_X 	state: 1434
# code:      ABS_X 	state: 1431
# code:      ABS_X 	state: 1427
# code:      ABS_X 	state: 1421
# code:      ABS_X 	state: 1415
# code:      ABS_X 	state: 1410
# code:      ABS_X 	state: 1405
# code:      ABS_X 	state: 1413
# code:      ABS_Y 	state: 1108
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1605
# code:      ABS_Y 	state: 1499
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1478
# code:      ABS_Y 	state: 1318
# code:      ABS_Y 	state: 1304
# code:      ABS_Y 	state: 1281
# code:      ABS_Y 	state: 1255
# code:      ABS_Y 	state: 1229
# code:      ABS_X 	state: 1491
# code:      ABS_Y 	state: 1090
# code:      ABS_X 	state: 1478
# code:      ABS_Y 	state: 1082
# code:      ABS_X 	state: 1466
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1457
# code:      ABS_X 	state: 1450
# code:      ABS_X 	state: 1444
# code:      ABS_X 	state: 1440
# code:      ABS_X 	state: 1436
# code:      ABS_X 	state: 1433
# code:      ABS_X 	state: 1431
# code:      ABS_X 	state: 1429
# code:      ABS_X 	state: 1427
# code:      ABS_X 	state: 1426
# code:      ABS_X 	state: 1424
# code:      ABS_X 	state: 1423
# code:      ABS_X 	state: 1421
# code:      ABS_X 	state: 1419
# code:      ABS_X 	state: 1418
# code:      ABS_X 	state: 1416
# code:      ABS_X 	state: 1414
# code:      ABS_X 	state: 1418
# code:      ABS_Y 	state: 1090
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1568
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1493
# code:      ABS_Y 	state: 1483
# code:      ABS_Y 	state: 1466
# code:      ABS_Y 	state: 1449
# code:      ABS_Y 	state: 1429
# code:      ABS_Y 	state: 1407
# code:      ABS_Y 	state: 1264
# code:      ABS_Y 	state: 1260
# code:      ABS_Y 	state: 1246
# code:      ABS_Y 	state: 1226
# code:      ABS_Y 	state: 1204
# code:      ABS_Y 	state: 1047
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1491
# code:      ABS_X 	state: 1480
# code:      ABS_X 	state: 1470
# code:      ABS_X 	state: 1461
# code:      ABS_X 	state: 1454
# code:      ABS_X 	state: 1448
# code:      ABS_X 	state: 1444
# code:      ABS_X 	state: 1440
# code:      ABS_X 	state: 1437
# code:      ABS_X 	state: 1434
# code:      ABS_X 	state: 1432
# code:      ABS_X 	state: 1431
# code:      ABS_X 	state: 1429
# code:      ABS_X 	state: 1427
# code:      ABS_X 	state: 1426
# code:      ABS_X 	state: 1422
# code:      ABS_X 	state: 1418
# code:      ABS_X 	state: 1441
# code:      ABS_Y 	state: 1252
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1595
# code:      ABS_Y 	state: 1457
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1407
# code:      ABS_Y 	state: 1401
# code:      ABS_Y 	state: 1390
# code:      ABS_Y 	state: 1371
# code:      ABS_Y 	state: 1346
# code:      ABS_Y 	state: 1185
# code:      ABS_Y 	state: 1175
# code:      ABS_Y 	state: 1159
# code:      ABS_Y 	state: 1023
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1499
# code:      ABS_X 	state: 1491
# code:      ABS_X 	state: 1485
# code:      ABS_X 	state: 1479
# code:      ABS_X 	state: 1475
# code:      ABS_X 	state: 1472
# code:      ABS_X 	state: 1469
# code:      ABS_X 	state: 1466
# code:      ABS_X 	state: 1460
# code:      ABS_X 	state: 1453
# code:      ABS_X 	state: 1447
# code:      ABS_X 	state: 1441
# code:      ABS_X 	state: 1437
# code:      ABS_X 	state: 1434
# code:      ABS_X 	state: 1431
# code:      ABS_X 	state: 1429
# code:      ABS_X 	state: 1427
# code:      ABS_X 	state: 1426
# code:      ABS_X 	state: 1424
# code:      ABS_X 	state: 1423
# code:      ABS_X 	state: 1421
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1525
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1490
# code:      ABS_Y 	state: 1465
# code:      ABS_Y 	state: 1322
# code:      ABS_Y 	state: 1308
# code:      ABS_Y 	state: 1283
# code:      ABS_Y 	state: 1135
# code:      ABS_Y 	state: 1126
# code:      ABS_Y 	state: 1104
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1493
# code:      ABS_X 	state: 1487
# code:      ABS_X 	state: 1481
# code:      ABS_X 	state: 1477
# code:      ABS_X 	state: 1474
# code:      ABS_X 	state: 1471
# code:      ABS_X 	state: 1469
# code:      ABS_X 	state: 1467
# code:      ABS_X 	state: 1466
# code:      ABS_X 	state: 1464
# code:      ABS_X 	state: 1462
# code:      ABS_X 	state: 1461
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1422
# code:      ABS_Y 	state: 1406
# code:      ABS_Y 	state: 1218
# code:      ABS_Y 	state: 1200
# code:      ABS_Y 	state: 1040
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1495
# code:      ABS_X 	state: 1489
# code:      ABS_X 	state: 1485
# code:      ABS_X 	state: 1482
# code:      ABS_X 	state: 1479
# code:      ABS_X 	state: 1476
# code:      ABS_X 	state: 1474
# code:      ABS_X 	state: 1473
# code:      ABS_X 	state: 1471
# code:      ABS_X 	state: 1469
# code:      ABS_X 	state: 1468
# code:      ABS_Y 	state: 1001
# code:      ABS_Y 	state: 1016
# code:      ABS_X 	state: 1476
# code:      ABS_Y 	state: 1042
# code:      ABS_X 	state: 1490
# code:      ABS_Y 	state: 1244
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1262
# code:      ABS_Y 	state: 1434
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1378
# code:      ABS_Y 	state: 1174
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1001
# code:      ABS_Y 	state: 1003
# code:      ABS_Y 	state: 1005
# code:      ABS_Y 	state: 1008
# code:      ABS_Y 	state: 1011
# code:      ABS_Y 	state: 1015
# code:      ABS_Y 	state: 1022
# code:      ABS_Y 	state: 1030
# code:      ABS_Y 	state: 1041
# code:      ABS_Y 	state: 1054
# code:      ABS_Y 	state: 1066
# code:      ABS_Y 	state: 1076
# code:      ABS_Y 	state: 1085
# code:      ABS_Y 	state: 1092
# code:      ABS_Y 	state: 1097
# code:      ABS_Y 	state: 1101
# code:      ABS_Y 	state: 1105
# code:      ABS_Y 	state: 1107
# code:      ABS_Y 	state: 1109
# code:      ABS_Y 	state: 1111
# code:      ABS_Y 	state: 1105
# code:      ABS_Y 	state: 1088
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1100
# code:      ABS_Y 	state: 1122
# code:      ABS_Y 	state: 1353
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1628
# code:      ABS_Y 	state: 1650
# code:      ABS_Y 	state: 1869
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1972
# code:      ABS_Y 	state: 1965
# code:      ABS_Y 	state: 1955
# code:      ABS_Y 	state: 1943
# code:      ABS_Y 	state: 1930
# code:      ABS_Y 	state: 1910
# code:      ABS_Y 	state: 1745
# code:      ABS_Y 	state: 1509
# code:      ABS_Y 	state: 1500
# code:      ABS_X 	state: 1505
# code:      ABS_X 	state: 1515
# code:      ABS_X 	state: 1524
# code:      ABS_X 	state: 1530
# code:      ABS_X 	state: 1536
# code:      ABS_X 	state: 1541
# code:      ABS_X 	state: 1544
# code:      ABS_X 	state: 1547
# code:      ABS_X 	state: 1549
# code:      ABS_X 	state: 1553
# code:      ABS_X 	state: 1551
# code:      ABS_X 	state: 1549
# code:      ABS_X 	state: 1548
# code:      ABS_X 	state: 1546
# code:      ABS_X 	state: 1544
# code:      ABS_X 	state: 1543
# code:      ABS_X 	state: 1542
# code:      ABS_X 	state: 1540
# code:      ABS_X 	state: 1538
# code:      ABS_X 	state: 1523
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1428
# code:      ABS_Y 	state: 1415
# code:      ABS_Y 	state: 1390
# code:      ABS_Y 	state: 1205
# code:      ABS_Y 	state: 1191
# code:      ABS_Y 	state: 1168
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1495
# code:      ABS_X 	state: 1489
# code:      ABS_X 	state: 1484
# code:      ABS_X 	state: 1480
# code:      ABS_X 	state: 1476
# code:      ABS_X 	state: 1474
# code:      ABS_X 	state: 1472
# code:      ABS_X 	state: 1470
# code:      ABS_X 	state: 1469
# code:      ABS_X 	state: 1467
# code:      ABS_X 	state: 1465
# code:      ABS_X 	state: 1467
# code:      ABS_X 	state: 1470
# code:      ABS_Y 	state: 1001
# code:      ABS_X 	state: 1471
# code:      ABS_Y 	state: 1003
# code:      ABS_X 	state: 1474
# code:      ABS_Y 	state: 1006
# code:      ABS_X 	state: 1476
# code:      ABS_Y 	state: 1008
# code:      ABS_X 	state: 1479
# code:      ABS_X 	state: 1482
# code:      ABS_X 	state: 1487
# code:      ABS_X 	state: 1496
# code:      ABS_Y 	state: 1011
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1015
# code:      ABS_Y 	state: 1023
# code:      ABS_Y 	state: 1037
# code:      ABS_Y 	state: 1053
# code:      ABS_Y 	state: 1067
# code:      ABS_Y 	state: 1079
# code:      ABS_Y 	state: 1089
# code:      ABS_Y 	state: 1097
# code:      ABS_Y 	state: 1104
# code:      ABS_Y 	state: 1110
# code:      ABS_Y 	state: 1115
# code:      ABS_Y 	state: 1124
# code:      ABS_Y 	state: 1134
# code:      ABS_Y 	state: 1147
# code:      ABS_Y 	state: 1168
# code:      ABS_Y 	state: 1308
# code:      ABS_Y 	state: 1321
# code:      ABS_Y 	state: 1343
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1380
# code:      ABS_Y 	state: 1356
# code:      ABS_Y 	state: 1164
# code:      ABS_Y 	state: 1149
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1498
# code:      ABS_X 	state: 1484
# code:      ABS_X 	state: 1473
# code:      ABS_X 	state: 1464
# code:      ABS_X 	state: 1457
# code:      ABS_X 	state: 1452
# code:      ABS_X 	state: 1447
# code:      ABS_X 	state: 1443
# code:      ABS_X 	state: 1440
# code:      ABS_X 	state: 1438
# code:      ABS_X 	state: 1436
# code:      ABS_X 	state: 1435
# code:      ABS_X 	state: 1432
# code:      ABS_X 	state: 1431
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1522
# code:      ABS_Y 	state: 1544
# code:      ABS_Y 	state: 1774
# code:      ABS_Y 	state: 1796
# code:      ABS_Y 	state: 1989
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1856
# code:      ABS_Y 	state: 1564
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1334
# code:      ABS_Y 	state: 1169
# code:      ABS_Y 	state: 1144
# code:      ABS_X 	state: 1474
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1470
# code:      ABS_X 	state: 1461
# code:      ABS_X 	state: 1452
# code:      ABS_X 	state: 1444
# code:      ABS_X 	state: 1437
# code:      ABS_X 	state: 1432
# code:      ABS_X 	state: 1428
# code:      ABS_X 	state: 1425
# code:      ABS_X 	state: 1422
# code:      ABS_X 	state: 1420
# code:      ABS_X 	state: 1419
# code:      ABS_X 	state: 1417
# code:      ABS_X 	state: 1415
# code:      ABS_X 	state: 1414
# code:      ABS_Y 	state: 1055
# code:      ABS_X 	state: 1416
# code:      ABS_Y 	state: 1071
# code:      ABS_X 	state: 1425
# code:      ABS_Y 	state: 1245
# code:      ABS_X 	state: 1444
# code:      ABS_Y 	state: 1265
# code:      ABS_X 	state: 1469
# code:      ABS_Y 	state: 1419
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1550
# code:      ABS_Y 	state: 1572
# code:      ABS_Y 	state: 1772
# code:      ABS_Y 	state: 1791
# code:      ABS_Y 	state: 1927
# code:      ABS_Y 	state: 2000
# code:      ABS_X 	state: 1508
# code:      ABS_X 	state: 1522
# code:      ABS_X 	state: 1533
# code:      ABS_X 	state: 1543
# code:      ABS_X 	state: 1550
# code:      ABS_X 	state: 1556
# code:      ABS_X 	state: 1560
# code:      ABS_X 	state: 1564
# code:      ABS_X 	state: 1567
# code:      ABS_X 	state: 1569
# code:      ABS_X 	state: 1572
# code:      ABS_X 	state: 1575
# code:      ABS_X 	state: 1578
# code:      ABS_X 	state: 1582
# code:      ABS_X 	state: 1587
# code:      ABS_X 	state: 1591
# code:      ABS_X 	state: 1594
# code:      ABS_X 	state: 1596
# code:      ABS_X 	state: 1598
# code:      ABS_X 	state: 1601
# code:      ABS_X 	state: 1603
# code:      ABS_X 	state: 1605
# code:      ABS_X 	state: 1602
# code:      ABS_Y 	state: 1988
# code:      ABS_X 	state: 1594
# code:      ABS_Y 	state: 1978
# code:      ABS_X 	state: 1583
# code:      ABS_Y 	state: 1962
# code:      ABS_X 	state: 1570
# code:      ABS_Y 	state: 1936
# code:      ABS_X 	state: 1551
# code:      ABS_Y 	state: 1750
# code:      ABS_X 	state: 1529
# code:      ABS_Y 	state: 1732
# code:      ABS_X 	state: 1505
# code:      ABS_Y 	state: 1582
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1560
# code:      ABS_Y 	state: 1500
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:      ABS_Y 	state: 1506
# code:      ABS_Y 	state: 1523
# code:      ABS_Y 	state: 1537
# code:      ABS_Y 	state: 1550
# code:      ABS_Y 	state: 1564
# code:      ABS_Y 	state: 1580
# code:      ABS_Y 	state: 1596
# code:      ABS_Y 	state: 1614
# code:      ABS_Y 	state: 1633
# code:      ABS_Y 	state: 1656
# code:      ABS_Y 	state: 1678
# code:      ABS_Y 	state: 1697
# code:      ABS_Y 	state: 1712
# code:      ABS_Y 	state: 1723
# code:      ABS_Y 	state: 1732
# code:      ABS_Y 	state: 1739
# code:      ABS_Y 	state: 1741
# code:      ABS_Y 	state: 1737
# code:      ABS_Y 	state: 1726
# code:      ABS_Y 	state: 1710
# code:      ABS_Y 	state: 1689
# code:      ABS_Y 	state: 1669
# code:      ABS_Y 	state: 1646
# code:      ABS_Y 	state: 1621
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1481
# code:      ABS_Y 	state: 1477
# code:      ABS_Y 	state: 1461
# code:      ABS_Y 	state: 1440
# code:      ABS_Y 	state: 1414
# code:      ABS_Y 	state: 1255
# code:      ABS_Y 	state: 1247
# code:      ABS_Y 	state: 1234
# code:      ABS_Y 	state: 1218
# code:      ABS_Y 	state: 1200
# code:      ABS_Y 	state: 1179
# code:      ABS_Y 	state: 1153
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1498
# code:      ABS_X 	state: 1496
# code:      ABS_X 	state: 1495
# code:      ABS_X 	state: 1497
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1059
# code:      ABS_Y 	state: 1366
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1531
# code:      ABS_Y 	state: 1542
# code:      ABS_Y 	state: 1563
# code:      ABS_Y 	state: 1698
# code:      ABS_Y 	state: 1707
# code:      ABS_Y 	state: 1721
# code:      ABS_Y 	state: 1739
# code:      ABS_Y 	state: 1765
# code:      ABS_Y 	state: 1904
# code:      ABS_X 	state: 1504
# code:      ABS_Y 	state: 1912
# code:      ABS_X 	state: 1511
# code:      ABS_Y 	state: 2000
# code:      ABS_X 	state: 1515
# code:      ABS_Y 	state: 1954
# code:      ABS_Y 	state: 1952
# code:      ABS_Y 	state: 1951
# code:      ABS_Y 	state: 1949
# code:      ABS_X 	state: 1510
# code:      ABS_Y 	state: 1937
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1732
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1518
# code:      ABS_Y 	state: 1537
# code:      ABS_Y 	state: 1554
# code:      ABS_Y 	state: 1568
# code:      ABS_Y 	state: 1581
# code:      ABS_Y 	state: 1591
# code:      ABS_Y 	state: 1600
# code:      ABS_Y 	state: 1608
# code:      ABS_Y 	state: 1617
# code:      ABS_Y 	state: 1626
# code:      ABS_Y 	state: 1633
# code:      ABS_Y 	state: 1641
# code:      ABS_Y 	state: 1649
# code:      ABS_Y 	state: 1656
# code:      ABS_Y 	state: 1659
# code:      ABS_Y 	state: 1653
# code:      ABS_Y 	state: 1501
# code:      ABS_Y 	state: 1500
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:      ABS_Y 	state: 1359
# code:      ABS_Y 	state: 1342
# code:      ABS_Y 	state: 1195
# code:      ABS_Y 	state: 1182
# code:      ABS_Y 	state: 1161
# code:      ABS_Y 	state: 1136
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1132
# code:      ABS_Y 	state: 1364
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1650
# code:      ABS_Y 	state: 1669
# code:      ABS_Y 	state: 1859
# code:      ABS_Y 	state: 1880
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1983
# code:      ABS_Y 	state: 1968
# code:      ABS_Y 	state: 1740
# code:      ABS_Y 	state: 1495
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1535
# code:      ABS_Y 	state: 1554
# code:      ABS_Y 	state: 1744
# code:      ABS_Y 	state: 1765
# code:      ABS_Y 	state: 1928
# code:      ABS_X 	state: 1618
# code:      ABS_Y 	state: 2000
# code:      ABS_X 	state: 1621
# code:      ABS_X 	state: 1622
# code:      ABS_X 	state: 1619
# code:      ABS_Y 	state: 1955
# code:      ABS_X 	state: 1611
# code:      ABS_Y 	state: 1946
# code:      ABS_X 	state: 1597
# code:      ABS_Y 	state: 1928
# code:      ABS_X 	state: 1580
# code:      ABS_Y 	state: 1784
# code:      ABS_X 	state: 1557
# code:      ABS_Y 	state: 1770
# code:      ABS_X 	state: 1532
# code:      ABS_Y 	state: 1637
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1400
# code:      ABS_Y 	state: 1391
# code:      ABS_Y 	state: 1373
# code:      ABS_Y 	state: 1348
# code:      ABS_Y 	state: 1180
# code:      ABS_Y 	state: 1170
# code:      ABS_Y 	state: 1150
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1506
# code:      ABS_Y 	state: 1500
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:   BTN_WEST 	state: 1
# code:   BTN_WEST 	state: 0
# code:   BTN_WEST 	state: 1
# code:   BTN_WEST 	state: 0
# code:   BTN_WEST 	state: 1
# code:   BTN_WEST 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:      ABS_Y 	state: 1593
# code:      ABS_Y 	state: 1782
# code:      ABS_Y 	state: 1976
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1962
# code:      ABS_Y 	state: 1949
# code:      ABS_Y 	state: 1801
# code:      ABS_Y 	state: 1782
# code:      ABS_Y 	state: 1608
# code:      ABS_Y 	state: 1593
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1378
# code:      ABS_Y 	state: 1356
# code:      ABS_Y 	state: 1177
# code:      ABS_Y 	state: 1162
# code:      ABS_Y 	state: 1011
# code:      ABS_Y 	state: 1000
# code:      ABS_Y 	state: 1055
# code:      ABS_Y 	state: 1346
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1369
# code:      ABS_Y 	state: 1358
# code:      ABS_Y 	state: 1336
# code:      ABS_Y 	state: 1181
# code:      ABS_Y 	state: 1172
# code:      ABS_Y 	state: 1162
# code:      ABS_Y 	state: 1146
# code:      ABS_Y 	state: 1127
# code:      ABS_Y 	state: 1103
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1493
# code:      ABS_X 	state: 1487
# code:      ABS_X 	state: 1482
# code:      ABS_X 	state: 1478
# code:      ABS_X 	state: 1474
# code:      ABS_X 	state: 1472
# code:      ABS_X 	state: 1470
# code:      ABS_X 	state: 1468
# code:      ABS_X 	state: 1467
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1521
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1358
# code:      ABS_Y 	state: 1337
# code:      ABS_Y 	state: 1166
# code:      ABS_Y 	state: 1148
# code:      ABS_Y 	state: 1000
# code:      ABS_X 	state: 1430
# code:      ABS_X 	state: 1426
# code:      ABS_X 	state: 1423
# code:      ABS_X 	state: 1421
# code:      ABS_X 	state: 1419
# code:      ABS_X 	state: 1418
# code:      ABS_X 	state: 1416
# code:      ABS_X 	state: 1414
# code:  BTN_SOUTH 	state: 1
# code:      ABS_X 	state: 1413
# code:      ABS_X 	state: 1417
# code:      ABS_X 	state: 1424
# code:      ABS_X 	state: 1433
# code:      ABS_X 	state: 1447
# code:      ABS_X 	state: 1464
# code:      ABS_X 	state: 1479
# code:      ABS_X 	state: 1494
# code:      ABS_Y 	state: 1052
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1066
# code:      ABS_Y 	state: 1089
# code:      ABS_Y 	state: 1254
# code:      ABS_Y 	state: 1265
# code:      ABS_Y 	state: 1282
# code:      ABS_Y 	state: 1301
# code:      ABS_Y 	state: 1321
# code:      ABS_Y 	state: 1461
# code:      ABS_Y 	state: 1470
# code:      ABS_Y 	state: 1490
# code:      ABS_Y 	state: 1500
# code:  BTN_SOUTH 	state: 0
# code:      ABS_Y 	state: 1721
# code:      ABS_Y 	state: 1856
# code:      ABS_Y 	state: 1882
# code:      ABS_Y 	state: 2000
# code:      ABS_Y 	state: 1902
# code:      ABS_Y 	state: 1878
# code:      ABS_Y 	state: 1616
# code:  BTN_SOUTH 	state: 1
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1312
# code:      ABS_Y 	state: 1128
# code:      ABS_Y 	state: 1000
# code:  BTN_SOUTH 	state: 0
# code:      ABS_Y 	state: 1066
# code:      ABS_Y 	state: 1215
# code:      ABS_Y 	state: 1405
# code:      ABS_Y 	state: 1500
# code:      ABS_Y 	state: 1506
# code:  BTN_SOUTH 	state: 1
# code:      ABS_Y 	state: 1521
# code:      ABS_Y 	state: 1660
# code:      ABS_Y 	state: 1673
# code:      ABS_Y 	state: 1693
# code:      ABS_Y 	state: 1715
# code:      ABS_Y 	state: 1741
# code:      ABS_Y 	state: 1765
# code:      ABS_Y 	state: 1784
# code:      ABS_Y 	state: 1798
# code:      ABS_Y 	state: 1801
# code:      ABS_Y 	state: 1794
# code:      ABS_Y 	state: 1770
# code:      ABS_Y 	state: 1592
# code:      ABS_Y 	state: 1577
# code:      ABS_Y 	state: 1500
# code:  BTN_SOUTH 	state: 0
# code:      ABS_Y 	state: 1310
# code:      ABS_Y 	state: 1111
# code:      ABS_Y 	state: 1000
# code:  BTN_SOUTH 	state: 1
# code:  BTN_SOUTH 	state: 0
# code:  BTN_SOUTH 	state: 1
# code:      ABS_X 	state: 1499
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1004
# code:      ABS_Y 	state: 1008
# code:      ABS_Y 	state: 1013
# code:      ABS_Y 	state: 1018
# code:      ABS_Y 	state: 1023
# code:      ABS_Y 	state: 1028
# code:      ABS_Y 	state: 1031
# code:  BTN_SOUTH 	state: 0
# code:      ABS_Y 	state: 1035
# code:      ABS_Y 	state: 1038
# code:      ABS_Y 	state: 1041
# code:      ABS_Y 	state: 1045
# code:      ABS_X 	state: 1498
# code:      ABS_Y 	state: 1050
# code:      ABS_X 	state: 1488
# code:      ABS_Y 	state: 1057
# code:      ABS_X 	state: 1476
# code:      ABS_Y 	state: 1065
# code:      ABS_X 	state: 1464
# code:      ABS_Y 	state: 1074
# code:      ABS_X 	state: 1453
# code:      ABS_Y 	state: 1083
# code:      ABS_X 	state: 1443
# code:      ABS_Y 	state: 1091
# code:      ABS_X 	state: 1436
# code:      ABS_Y 	state: 1097
# code:      ABS_X 	state: 1430
# code:      ABS_Y 	state: 1102
# code:      ABS_X 	state: 1425
# code:      ABS_Y 	state: 1106
# code:      ABS_X 	state: 1421
# code:      ABS_Y 	state: 1109
# code:      ABS_X 	state: 1418
# code:      ABS_Y 	state: 1112
# code:      ABS_X 	state: 1415
# code:      ABS_Y 	state: 1114
# code:      ABS_X 	state: 1413
# code:      ABS_X 	state: 1412
# code:      ABS_Y 	state: 1117
# code:      ABS_X 	state: 1410
# code:      ABS_Y 	state: 1119
# code:      ABS_X 	state: 1408
# code:      ABS_X 	state: 1407
# code:      ABS_Y 	state: 1121
# code:      ABS_Y 	state: 1124
# code:      ABS_X 	state: 1405
# code:      ABS_Y 	state: 1135
# code:      ABS_Y 	state: 1156
# code:      ABS_Y 	state: 1323
# code:      ABS_Y 	state: 1337
# code:      ABS_X 	state: 1412
# code:      ABS_Y 	state: 1472
# code:      ABS_X 	state: 1430
# code:      ABS_Y 	state: 1482
# code:      ABS_X 	state: 1500
# code:      ABS_Y 	state: 1500
# code:      ABS_Z 	state: 6
# code:      ABS_Z 	state: 7
# code:      ABS_Z 	state: 6
# ...
# code:      ABS_Y 	state: 1153
# code:     ABS_RX 	state: 1832
# code:      ABS_Y 	state: 1157
# code:     ABS_RX 	state: 1978
# code:      ABS_Y 	state: 1161
# code:     ABS_RX 	state: 2000
# code:      ABS_Y 	state: 1166
# code:      ABS_Y 	state: 1173
# code:      ABS_Y 	state: 1181
# code:      ABS_Y 	state: 1192
# code:      ABS_Y 	state: 1203
# code:      ABS_Y 	state: 1214
# code:      ABS_Y 	state: 1228
# code:      ABS_Y 	state: 1244
# code:      ABS_Y 	state: 1261
# code:      ABS_Y 	state: 1277
# code:      ABS_Y 	state: 1292
# code:     ABS_RX 	state: 1934
# code:      ABS_Y 	state: 1305
# code:     ABS_RX 	state: 1913
# code:      ABS_Y 	state: 1318
# code:     ABS_RX 	state: 1715
# code:      ABS_Y 	state: 1330
# code:     ABS_RX 	state: 1696
# code:      ABS_Y 	state: 1341
# code:     ABS_RX 	state: 1529
# code:      ABS_Y 	state: 1351
# code:     ABS_RX 	state: 1514
# code:      ABS_Y 	state: 1360
# code:     ABS_RX 	state: 1500
# code:      ABS_Y 	state: 1368
# code:      ABS_Y 	state: 1375
# code:      ABS_Y 	state: 1382
# code:      ABS_Y 	state: 1388
# code:      ABS_Y 	state: 1395
# code:      ABS_Y 	state: 1401
# code:      ABS_Y 	state: 1406
# code:      ABS_Y 	state: 1412
# code:      ABS_Y 	state: 1417
# code:      ABS_Y 	state: 1423
# code:     ABS_RX 	state: 1604
# code:      ABS_Y 	state: 1429
# code:     ABS_RX 	state: 1628
# code:      ABS_Y 	state: 1434
# code:     ABS_RX 	state: 1855
# code:      ABS_Y 	state: 1438
# code:     ABS_RX 	state: 1881
# code:      ABS_Y 	state: 1443
# code:     ABS_RX 	state: 2000
# code:      ABS_Y 	state: 1446
# code:      ABS_Y 	state: 1449
# code:      ABS_Y 	state: 1451
# code:      ABS_Y 	state: 1454
# code:      ABS_Y 	state: 1456
# code:      ABS_Y 	state: 1458
# code:     ABS_RX 	state: 1923
# code:     ABS_RX 	state: 1899
# code:      ABS_Y 	state: 1460
# code:     ABS_RX 	state: 1681
# code:     ABS_RX 	state: 1660
# code:     ABS_RX 	state: 1500
# code:      ABS_Y 	state: 1462
# code:      ABS_Y 	state: 1465
# code:      ABS_Y 	state: 1467
# code:      ABS_Y 	state: 1472
# code:      ABS_Y 	state: 1476
# code:      ABS_Y 	state: 1482
# code:      ABS_Y 	state: 1489
# code:      ABS_Y 	state: 1498
# code:      ABS_Y 	state: 1500
# code:     ABS_RY 	state: 1518
# code:     ABS_RY 	state: 1538
# code:     ABS_RY 	state: 1737
# code:     ABS_RY 	state: 1757
# code:     ABS_RY 	state: 1934
# code:     ABS_RY 	state: 2000
# code:     ABS_RY 	state: 1995
# code:     ABS_RY 	state: 1984
# code:     ABS_RY 	state: 1964
# code:     ABS_RY 	state: 1804
# code:     ABS_RY 	state: 1786
# code:     ABS_RX 	state: 1496
# code:     ABS_RY 	state: 1620
# code:     ABS_RX 	state: 1492
# code:     ABS_RY 	state: 1608
# code:     ABS_RX 	state: 1490
# code:     ABS_RY 	state: 1583
# code:     ABS_RX 	state: 1499
# code:     ABS_RY 	state: 1500
# code:     ABS_RX 	state: 1500
# code:     ABS_RY 	state: 1467
# code:     ABS_RY 	state: 1457
# code:     ABS_RY 	state: 1442
# code:     ABS_RY 	state: 1420
# code:     ABS_RY 	state: 1288
# code:     ABS_RY 	state: 1274
# code:     ABS_RY 	state: 1252
# code:     ABS_RY 	state: 1119
# code:     ABS_RY 	state: 1108
# code:     ABS_RY 	state: 1000
# code:     ABS_RY 	state: 1089
# code:     ABS_RY 	state: 1500
# code:     ABS_RY 	state: 1411
# code:     ABS_RY 	state: 1398
# code:     ABS_RY 	state: 1375
# code:     ABS_RY 	state: 1178
# code:     ABS_RY 	state: 1163
# code:     ABS_RY 	state: 1005
# code:     ABS_RY 	state: 1000
# code:     ABS_RX 	state: 1511
# code:     ABS_RX 	state: 1522
# code:     ABS_RX 	state: 1531
# code:     ABS_RX 	state: 1538
# code:     ABS_RX 	state: 1543
# code:     ABS_RX 	state: 1547
# code:     ABS_RX 	state: 1551
# code:     ABS_RX 	state: 1554
# code:     ABS_RX 	state: 1556
# code:     ABS_RX 	state: 1559
# code:     ABS_RX 	state: 1556
# code:     ABS_RX 	state: 1550
# code:     ABS_RY 	state: 1027
# code:     ABS_RX 	state: 1539
# code:     ABS_RY 	state: 1044
# code:     ABS_RX 	state: 1528
# code:     ABS_RY 	state: 1194
# code:     ABS_RX 	state: 1518
# code:     ABS_RY 	state: 1331
# code:     ABS_RX 	state: 1500
# code:     ABS_RY 	state: 1500
# code:   BTN_WEST 	state: 1
# code:   BTN_WEST 	state: 0
# code:     ABS_RX 	state: 1447
# code:     ABS_RX 	state: 1290
# code:     ABS_RX 	state: 1114
# code:     ABS_RX 	state: 1000
# code:     ABS_RY 	state: 1466
# code:     ABS_RY 	state: 1455
# code:     ABS_RY 	state: 1445
# code:     ABS_RX 	state: 1022
# code:     ABS_RY 	state: 1437
# code:     ABS_RX 	state: 1327
# code:     ABS_RY 	state: 1453
# code:     ABS_RX 	state: 1500
# code:     ABS_RY 	state: 1500
# code:     ABS_RX 	state: 1288
# code:     ABS_RX 	state: 1058
# code:     ABS_RX 	state: 1000
# code:     ABS_RY 	state: 1499
# code:     ABS_RY 	state: 1496
# code:     ABS_RY 	state: 1493
# code:     ABS_RY 	state: 1491
# code:     ABS_RY 	state: 1489
# code:     ABS_RX 	state: 1019
# code:     ABS_RY 	state: 1497
# code:     ABS_RX 	state: 1042
# code:     ABS_RY 	state: 1500
# code:     ABS_RX 	state: 1296
# code:     ABS_RX 	state: 1500
# code:     ABS_RX 	state: 1459
# code:     ABS_RX 	state: 1302
# code:     ABS_RX 	state: 1122
# code:     ABS_RX 	state: 1000
# code:     ABS_RX 	state: 1023
# code:     ABS_RX 	state: 1036
# code:     ABS_RX 	state: 1055
# code:     ABS_RX 	state: 1208
# code:     ABS_RX 	state: 1221
# code:     ABS_RX 	state: 1362
# code:     ABS_RX 	state: 1365
# code:     ABS_RX 	state: 1374
# code:     ABS_RX 	state: 1383
# code:     ABS_RX 	state: 1394
# code:     ABS_RX 	state: 1418
# code:     ABS_RX 	state: 1500
# code:     ABS_RY 	state: 1868
# code:     ABS_RX 	state: 1444
# code:     ABS_RY 	state: 2000
# code:     ABS_RX 	state: 1440
# code:     ABS_RX 	state: 1437
# code:     ABS_RX 	state: 1434
# code:     ABS_RX 	state: 1432
# code:     ABS_RX 	state: 1430
# code:     ABS_RX 	state: 1428
# code:     ABS_RX 	state: 1423
# code:     ABS_RX 	state: 1419
# code:     ABS_RX 	state: 1415
# code:     ABS_RX 	state: 1411
# code:     ABS_RX 	state: 1409
# code:     ABS_RX 	state: 1407
# code:     ABS_RX 	state: 1405
# code:     ABS_RX 	state: 1404
# code:     ABS_RX 	state: 1402
# code:     ABS_RX 	state: 1400
# code:     ABS_RX 	state: 1399
# code:     ABS_RX 	state: 1396
# code:     ABS_RX 	state: 1392
# code:     ABS_RX 	state: 1388
# code:     ABS_RY 	state: 1984
# code:     ABS_RX 	state: 1384
# code:     ABS_RY 	state: 1965
# code:     ABS_RX 	state: 1381
# code:     ABS_RY 	state: 1747
# code:     ABS_RX 	state: 1500
# code:     ABS_RY 	state: 1500
# code:     ABS_RY 	state: 1394
# code:     ABS_RY 	state: 1262
# code:     ABS_RY 	state: 1090
# code:     ABS_RY 	state: 1000
# code:     ABS_RY 	state: 1243
# code:     ABS_RY 	state: 1679
# code:     ABS_RY 	state: 1398
# code:     ABS_RY 	state: 1500
# code:     ABS_RY 	state: 1516
# code:     ABS_RY 	state: 1741
# code:     ABS_RY 	state: 1897
# code:     ABS_RY 	state: 2000
# code:     ABS_RX 	state: 1404
# code:     ABS_RX 	state: 1398
# code:     ABS_RX 	state: 1393
# code:     ABS_RX 	state: 1388
# code:     ABS_RX 	state: 1385
# code:     ABS_RX 	state: 1382
# code:     ABS_RX 	state: 1380
# code:     ABS_RX 	state: 1378
# code:     ABS_RX 	state: 1377
# code:     ABS_RX 	state: 1375
# code:     ABS_RX 	state: 1373
# code:     ABS_RX 	state: 1372
# code:     ABS_RY 	state: 1954
# code:     ABS_RX 	state: 1379
# code:     ABS_RY 	state: 1938
# code:     ABS_RX 	state: 1389
# code:     ABS_RY 	state: 1736
# code:     ABS_RX 	state: 1401
# code:     ABS_RY 	state: 1581
# code:     ABS_RX 	state: 1412
# code:     ABS_RY 	state: 1500
# code:     ABS_RX 	state: 1420
# code:     ABS_RX 	state: 1427
# code:     ABS_RY 	state: 1405
# code:     ABS_RX 	state: 1432
# code:     ABS_RY 	state: 1216
# code:     ABS_RX 	state: 1437
# code:     ABS_RY 	state: 1068
# code:     ABS_RY 	state: 1000
# code:     ABS_RX 	state: 1444
# code:     ABS_RX 	state: 1450
# code:     ABS_RX 	state: 1454
# code:     ABS_RX 	state: 1458
# code:     ABS_RX 	state: 1461
# code:     ABS_RX 	state: 1464
# code:     ABS_RX 	state: 1466
# code:     ABS_RX 	state: 1468
# code:     ABS_RX 	state: 1459
# code:     ABS_RX 	state: 1445
# code:     ABS_RX 	state: 1432
# code:     ABS_RY 	state: 1091
# code:     ABS_RX 	state: 1422
# code:     ABS_RY 	state: 1283
# code:     ABS_RY 	state: 1492
# code:     ABS_RX 	state: 1439
# code:     ABS_RY 	state: 1500
# code:     ABS_RX 	state: 1460
# code:     ABS_RY 	state: 1596
# code:     ABS_RX 	state: 1476
# code:     ABS_RY 	state: 1742
# code:     ABS_RX 	state: 1491
# code:     ABS_RY 	state: 1926
# code:     ABS_RX 	state: 1500
# code:     ABS_RY 	state: 2000
# code:     ABS_RX 	state: 1289
# code:     ABS_RX 	state: 1264
# code:     ABS_RY 	state: 1924
# code:     ABS_RX 	state: 1090
# code:     ABS_RY 	state: 1902
# code:     ABS_RX 	state: 1078
# code:     ABS_RY 	state: 1721
# code:     ABS_RX 	state: 1063
# code:     ABS_RY 	state: 1704
# code:     ABS_RX 	state: 1000
# code:     ABS_RY 	state: 1680
# code:     ABS_RY 	state: 1537
# code:     ABS_RY 	state: 1532
# code:     ABS_RY 	state: 1527
# code:     ABS_RY 	state: 1523
# code:     ABS_RY 	state: 1519
# code:     ABS_RY 	state: 1517
# code:     ABS_RY 	state: 1514
# code:     ABS_RY 	state: 1513
# code:     ABS_RY 	state: 1511
# code:     ABS_RY 	state: 1509
# code:     ABS_RX 	state: 1015
# code:     ABS_RY 	state: 1507
# code:     ABS_RX 	state: 1163
# code:     ABS_RY 	state: 1505
# code:     ABS_RX 	state: 1367
# code:     ABS_RY 	state: 1504
# code:     ABS_RX 	state: 1500
# code:     ABS_RY 	state: 1500
# code:     ABS_RX 	state: 1615
# code:     ABS_RX 	state: 1776
# code:     ABS_RX 	state: 1943
# code:     ABS_RX 	state: 2000
# code:     ABS_RY 	state: 1483
# code:     ABS_RY 	state: 1466
# code:     ABS_RY 	state: 1451
# code:     ABS_RX 	state: 1984
# code:     ABS_RY 	state: 1439
# code:     ABS_RX 	state: 1974
# code:     ABS_RY 	state: 1429
# code:     ABS_RX 	state: 1952
# code:     ABS_RY 	state: 1421
# code:     ABS_RX 	state: 1759
# code:     ABS_RY 	state: 1417
# code:     ABS_RX 	state: 1606
# code:     ABS_RX 	state: 1500
# code:     ABS_RY 	state: 1430
# code:     ABS_RY 	state: 1500
# code:     ABS_RX 	state: 1391
# code:     ABS_RX 	state: 1141
# code:     ABS_RX 	state: 1000
# code:     ABS_RX 	state: 1087
# code:     ABS_RX 	state: 1250
# code:     ABS_RX 	state: 1500
# code:     ABS_RY 	state: 1599
# code:     ABS_RY 	state: 1611
# code:     ABS_RX 	state: 1723
# code:     ABS_RY 	state: 1636
# code:     ABS_RX 	state: 1937
# code:     ABS_RY 	state: 1779
# code:     ABS_RX 	state: 1945
# code:     ABS_RY 	state: 1768
# code:     ABS_RX 	state: 2000
# code:     ABS_RY 	state: 1744
# code:     ABS_RY 	state: 1588
# code:     ABS_RY 	state: 1575
# code:     ABS_RY 	state: 1557
# code:     ABS_RY 	state: 1536
# code:     ABS_RY 	state: 1512
# code:     ABS_RY 	state: 1500
# code:     ABS_RX 	state: 1983
# code:     ABS_RX 	state: 1970
# code:     ABS_RX 	state: 1814
# code:     ABS_RX 	state: 1790
# code:     ABS_RX 	state: 1500
# code:     ABS_RX 	state: 1378
# code:     ABS_RX 	state: 1200
# code:     ABS_RX 	state: 1000
# code:     ABS_RX 	state: 1011
# code:     ABS_RY 	state: 1464
# code:     ABS_RX 	state: 1027
# code:     ABS_RY 	state: 1455
# code:     ABS_RX 	state: 1224
# code:     ABS_RY 	state: 1446
# code:     ABS_RX 	state: 1399
# code:     ABS_RY 	state: 1439
# code:     ABS_RX 	state: 1500
# code:     ABS_RY 	state: 1446
# code:     ABS_RY 	state: 1469
# code:     ABS_RY 	state: 1489
# code:     ABS_RX 	state: 1521
# code:     ABS_RY 	state: 1500
# code:     ABS_RX 	state: 1734
# code:     ABS_RX 	state: 1902
# code:     ABS_RX 	state: 2000
# code:     ABS_RX 	state: 1960
# code:     ABS_RX 	state: 1821
# code:     ABS_RX 	state: 1584
# code:     ABS_RX 	state: 1500
# code:     ABS_RX 	state: 1373
# code:     ABS_RX 	state: 1200
# code:     ABS_RX 	state: 1035
# code:     ABS_RY 	state: 1407
# code:     ABS_RX 	state: 1000
# code:     ABS_RY 	state: 1412
# code:     ABS_RY 	state: 1424
# code:     ABS_RY 	state: 1440
# code:     ABS_RY 	state: 1458
# code:     ABS_RY 	state: 1474
# code:     ABS_RY 	state: 1491
# code:     ABS_RY 	state: 1500
# code:     ABS_RX 	state: 1126
# code:     ABS_RX 	state: 1382
# code:     ABS_RX 	state: 1500
# code:     ABS_RX 	state: 1691
# code:     ABS_RY 	state: 1601
# code:     ABS_RX 	state: 1980
# code:     ABS_RY 	state: 1616
# code:     ABS_RX 	state: 2000
# code:     ABS_RY 	state: 1623
# code:     ABS_RY 	state: 1621
# code:     ABS_RY 	state: 1616
# code:     ABS_RY 	state: 1608
# code:     ABS_RY 	state: 1598
# code:     ABS_RY 	state: 1583
# code:     ABS_RY 	state: 1566
# code:     ABS_RY 	state: 1549
# code:     ABS_RY 	state: 1530
# code:     ABS_RY 	state: 1509
# code:     ABS_RY 	state: 1500
# code:     ABS_RX 	state: 1912
# code:     ABS_RX 	state: 1661
# code:     ABS_RX 	state: 1500
# code:     ABS_RX 	state: 1442
# code:     ABS_RX 	state: 1224
# code:     ABS_RY 	state: 1492
# code:     ABS_RX 	state: 1012
# code:     ABS_RY 	state: 1329
# code:     ABS_RX 	state: 1000
# code:     ABS_RY 	state: 1340
# code:     ABS_RY 	state: 1356
# code:     ABS_RY 	state: 1379
# code:     ABS_RY 	state: 1500
# code:     ABS_RX 	state: 1071
# code:     ABS_RX 	state: 1092
# code:     ABS_RX 	state: 1328
# code:     ABS_RX 	state: 1491
# code:     ABS_RX 	state: 1500
# code:     ABS_RX 	state: 1544
# code:     ABS_RX 	state: 1570
# code:     ABS_RX 	state: 1782
# code:     ABS_RX 	state: 1807
# code:     ABS_RX 	state: 2000
# code:     ABS_RX 	state: 1982
# code:     ABS_RX 	state: 1973
# code:     ABS_RX 	state: 1958
# code:     ABS_RX 	state: 1932
# code:     ABS_RX 	state: 1757
# code:     ABS_RX 	state: 1740
# code:     ABS_RX 	state: 1558
# code:     ABS_RX 	state: 1500
# code:      ABS_X 	state: 1408
# code:      ABS_X 	state: 1257
# code:      ABS_X 	state: 1086
# code:      ABS_X 	state: 1000
# code:      ABS_X 	state: 1041
# code:      ABS_X 	state: 1737
# code:     ABS_RX 	state: 1580
# code:      ABS_X 	state: 1500
# code:     ABS_RX 	state: 1591
# code:     ABS_RX 	state: 1608
# code:     ABS_RX 	state: 1623
# code:     ABS_RX 	state: 1635
# code:     ABS_RX 	state: 1644
# code:     ABS_RX 	state: 1652
# code:     ABS_RX 	state: 1658
# code:     ABS_RX 	state: 1663
# code:     ABS_RX 	state: 1665
# code:     ABS_RX 	state: 1662
# code:     ABS_RX 	state: 1652
# code:     ABS_RX 	state: 1636
# code:     ABS_RX 	state: 1615
# code:     ABS_RX 	state: 1591
# code:     ABS_RX 	state: 1567
# code:     ABS_RX 	state: 1544
# code:     ABS_RX 	state: 1523
# code:     ABS_RX 	state: 1506
# code:     ABS_RX 	state: 1500
# code:     ABS_RX 	state: 1297
# code:     ABS_RX 	state: 1273
# code:      ABS_X 	state: 1507
# code:     ABS_RX 	state: 1033
# code:      ABS_X 	state: 1512
# code:     ABS_RX 	state: 1000
# code:      ABS_X 	state: 1517
# code:      ABS_X 	state: 1520
# code:      ABS_X 	state: 1523
# code:      ABS_X 	state: 1525
# code:      ABS_X 	state: 1528
# code:      ABS_X 	state: 1531
# code:      ABS_X 	state: 1540
# code:      ABS_X 	state: 1563
# code:      ABS_X 	state: 1720
# code:      ABS_X 	state: 1732
# code:      ABS_X 	state: 1750
# code:      ABS_X 	state: 1776
# code:      ABS_X 	state: 1940
# code:      ABS_X 	state: 2000
# code:     ABS_RX 	state: 1000
# code:     ABS_RX 	state: 1019
# code:     ABS_RX 	state: 1234
# code:     ABS_RX 	state: 1436
# code:     ABS_RX 	state: 1500
# code:     ABS_RX 	state: 1697
# code:     ABS_RX 	state: 1857
# code:     ABS_RX 	state: 2000
# code:      ABS_X 	state: 1964
# code:      ABS_X 	state: 1940
# code:      ABS_X 	state: 1694
# code:      ABS_X 	state: 1674
# code:      ABS_X 	state: 1650
# code:      ABS_X 	state: 1500
# code:     ABS_RX 	state: 1999
# code:     ABS_RX 	state: 1808
# code:     ABS_RX 	state: 1500
# code:     ABS_RX 	state: 1475
# code:     ABS_RX 	state: 1206
# code:     ABS_RX 	state: 1000
# code:     ABS_RX 	state: 1119
# code:     ABS_RY 	state: 1512
# code:     ABS_RX 	state: 1376
# code:     ABS_RY 	state: 1532
# code:     ABS_RX 	state: 1500
# code:     ABS_RY 	state: 1554
# code:     ABS_RX 	state: 1652
# code:     ABS_RY 	state: 1574
# code:     ABS_RX 	state: 1873
# code:     ABS_RY 	state: 1595
# code:      ABS_X 	state: 1395
# code:     ABS_RX 	state: 1894
# code:     ABS_RY 	state: 1613
# code:      ABS_X 	state: 1126
# code:     ABS_RX 	state: 1914
# code:     ABS_RY 	state: 1620
# code:      ABS_X 	state: 1000
# code:     ABS_RX 	state: 2000
# code:     ABS_RY 	state: 1612
# code:     ABS_RY 	state: 1590
# code:     ABS_RY 	state: 1564
# code:     ABS_RY 	state: 1500
# code:      ABS_X 	state: 1500
# code:      ABS_X 	state: 1714
# code:      ABS_X 	state: 1423
# code:      ABS_X 	state: 1520
# code:      ABS_X 	state: 1500
# code:     ABS_RX 	state: 1833
# code:     ABS_RX 	state: 1500
# code:     ABS_RX 	state: 1371
# code:     ABS_RX 	state: 1000
# code:     ABS_RX 	state: 1358
# code:     ABS_RX 	state: 1622
# code:     ABS_RX 	state: 1500

# %%
C
